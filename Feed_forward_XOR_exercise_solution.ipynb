# %% [markdown]
# <a href="https://colab.research.google.com/github/tillaczel/Machin-learning-workshop/blob/master/Feed_forward_XOR_exercise_solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Feed forward exercise
#
# Implement a feed forward neural network to correctly label the generated data.

# %%
# !pip install tensorflow --upgrade

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import numpy as np
import matplotlib.pyplot as plt
# Out:
# ...
#      |████████████████████████████████| 86.3MB 1.3MB/s
# ...
#      |████████████████████████████████| 3.8MB 20.8MB/s
# ...
#      |████████████████████████████████| 450kB 47.3MB/s
# ...
#   Found existing installation: tensorboard 1.15.0
#     Uninstalling tensorboard-1.15.0:
#       Successfully uninstalled tensorboard-1.15.0
#   Found existing installation: tensorflow-estimator 1.15.1
#     Uninstalling tensorflow-estimator-1.15.1:
#       Successfully uninstalled tensorflow-estimator-1.15.1
#   Found existing installation: tensorflow 1.15.0
#     Uninstalling tensorflow-1.15.0:
#       Successfully uninstalled tensorflow-1.15.0
# ...

# %%
x_train = np.random.rand(10000,2)*2-1
y_train = np.clip(x_train[:,0]*x_train[:,1]*np.inf,0,1)

fig = plt.figure(figsize=(12,12))
plt.scatter(x_train[:,0], x_train[:,1], c=y_train)
plt.show()

# %%
model = Sequential()
model.add(Dense(128, input_dim=2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='sgd',
              loss='mse')

history = model.fit(x_train, y_train, epochs=10, batch_size=32)
# Out:
# Train on 10000 samples
# Epoch 1/10
# 10000/10000 [==============================] - 1s 107us/sample - loss: 0.2425
# Epoch 2/10
# 10000/10000 [==============================] - 0s 45us/sample - loss: 0.2266
# Epoch 3/10
# 10000/10000 [==============================] - 0s 42us/sample - loss: 0.2124
# Epoch 4/10
# 10000/10000 [==============================] - 0s 45us/sample - loss: 0.1995
# Epoch 5/10
# 10000/10000 [==============================] - 0s 46us/sample - loss: 0.1877
# Epoch 6/10
# 10000/10000 [==============================] - 0s 46us/sample - loss: 0.1769
# Epoch 7/10
# 10000/10000 [==============================] - 0s 43us/sample - loss: 0.1667
# Epoch 8/10
# 10000/10000 [==============================] - 0s 44us/sample - loss: 0.1573
# Epoch 9/10
# 10000/10000 [==============================] - 0s 44us/sample - loss: 0.1485
# Epoch 10/10
# 10000/10000 [==============================] - 0s 43us/sample - loss: 0.1405

# %%
fig = plt.figure(figsize=(12,12))
plt.scatter(x_train[:,0], x_train[:,1], c=np.round(model.predict(x_train)[:,0]))
plt.show()
